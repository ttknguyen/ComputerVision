# %% [markdown]
# **Bài tập Segmentation**
#
# *   Tên: Thái Trần Khánh Nguyên
# *   MSSV: 19520188

# %%
from google.colab import drive
import os
import cv2 as cv
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# # Segmentation

# %%
dir_monhoc = '/gdrive/MyDrive/CS231.L22.KHCL'
dir_baitap = os.path.join(dir_monhoc, 'ImageSegmentation')

# %%
path_particles = os.path.join(dir_baitap, 'Phandoan01.jpg')
particles = cv.imread(path_particles, 0)
cv2_imshow(particles)
# Out:
# <PIL.Image.Image image mode=L size=385x310 at 0x7F897B4676D0>

# %%
def avgHist(img):
  % hist = np.histogram(img.flatten(),256,[0,256])
  hist = cv.calcHist([img],[0],None,[256],[0,256])

  plt.figure(figsize=(20,10))
  plt.plot(hist)
  plt.xlim(0, 256)
  plt.show()

  i, j = 0, hist.shape[0]
  while (hist[i] == 0): i += 1
  while (hist[j-1] == 0): j -= 1
  print(i, j)
  return (i + j) / 2

# %%
def Segmentation(img, t):
  tmp = img.copy()

  for i in range(tmp.shape[0]):
    for j in range(tmp.shape[1]):
      if (tmp[i][j] > t):
        tmp[i][j] = 0
      else:
        tmp[i][j] = 255

  return tmp

# %%
image_path = os.path.join(dir_baitap, 'Phandoan02.jpg')
image = cv.imread(image_path, 0)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=413x280 at 0x7F6458FCD1D0>

# %%
def AdaptiveSeg(f, nrow, ncol):
  g = f.copy()
  r = int(f.shape[0]/nrow)
  c = int(f.shape[1]/ncol)

  for i in range(nrow):
    for j in range(ncol):
      x = g[i*r:(i+1)*r, j*c:(j+1)*c].copy()

      cv2_imshow(x)

      % hist = np.histogram(x.flatten(),256,[0,256])
      hist = cv.calcHist([x],[0],None,[256],[0,256])

      plt.figure(figsize=(10,5))
      plt.plot(hist)
      plt.xlim(0, 256)
      plt.show()
      while (True): 
        t = int(input())
        if (t == 0):
          g[i*r:(i+1)*r, j*c:(j+1)*c] = x
          break
        x = g[i*r:(i+1)*r, j*c:(j+1)*c].copy()
        x = Segmentation(x, t)
        cv2_imshow(x)

  return g

# %%
image_path = os.path.join(dir_baitap, 'son1.jpg')
image = cv.imread(image_path, 0)
#(510, 384)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=335x330 at 0x7F89688FA910>

# %%
cv2_imshow(AdaptiveSeg(image[70:400, 35:370], 4, 4))
# Out:
# <PIL.Image.Image image mode=L size=83x82 at 0x7F8968897D90>
# 135
# <PIL.Image.Image image mode=L size=83x82 at 0x7F89687EE750>
# 0
# <PIL.Image.Image image mode=L size=83x82 at 0x7F8968262890>
# 170
# <PIL.Image.Image image mode=L size=83x82 at 0x7F89688A5290>
# 0
# <PIL.Image.Image image mode=L size=83x82 at 0x7F89682584D0>
# 190
# <PIL.Image.Image image mode=L size=83x82 at 0x7F8968262890>
# 0
# <PIL.Image.Image image mode=L size=83x82 at 0x7F8968262890>
# 1
# <PIL.Image.Image image mode=L size=83x82 at 0x7F8968804E50>
# 0
# <PIL.Image.Image image mode=L size=83x82 at 0x7F8968804E50>
# 105
# <PIL.Image.Image image mode=L size=83x82 at 0x7F89682584D0>
# 0
# <PIL.Image.Image image mode=L size=83x82 at 0x7F8968677F50>
# 135
# <PIL.Image.Image image mode=L size=83x82 at 0x7F8968611F10>
# 0
# <PIL.Image.Image image mode=L size=83x82 at 0x7F8968622E10>
# 155
# <PIL.Image.Image image mode=L size=83x82 at 0x7F8968622E90>
# 0
# <PIL.Image.Image image mode=L size=83x82 at 0x7F896847D990>
# 155
# <PIL.Image.Image image mode=L size=83x82 at 0x7F89682B0350>
# 0
# <PIL.Image.Image image mode=L size=83x82 at 0x7F896828B910>
# 80
# <PIL.Image.Image image mode=L size=83x82 at 0x7F89683102D0>
# 0
# <PIL.Image.Image image mode=L size=83x82 at 0x7F896838A8D0>
# 100
# <PIL.Image.Image image mode=L size=83x82 at 0x7F89683108D0>
# 0
# <PIL.Image.Image image mode=L size=83x82 at 0x7F89683DF4D0>
# 110
# <PIL.Image.Image image mode=L size=83x82 at 0x7F896D050DD0>
# 0
# <PIL.Image.Image image mode=L size=83x82 at 0x7F89682D7810>
# 110
# <PIL.Image.Image image mode=L size=83x82 at 0x7F8968DE6310>
# 0
# <PIL.Image.Image image mode=L size=83x82 at 0x7F896CFC65D0>
# 55
# <PIL.Image.Image image mode=L size=83x82 at 0x7F89688900D0>
# 0
# <PIL.Image.Image image mode=L size=83x82 at 0x7F89688A5250>
# 70
# <PIL.Image.Image image mode=L size=83x82 at 0x7F896842FD50>
# 0
# <PIL.Image.Image image mode=L size=83x82 at 0x7F896CFC65D0>
# 75
# <PIL.Image.Image image mode=L size=83x82 at 0x7F89686F2C10>
# 0
# <PIL.Image.Image image mode=L size=83x82 at 0x7F896865F650>
# 70
# <PIL.Image.Image image mode=L size=83x82 at 0x7F8968299050>
# 80
# <PIL.Image.Image image mode=L size=83x82 at 0x7F8968884DD0>
# 0
# <PIL.Image.Image image mode=L size=335x330 at 0x7F89682ABF10>

# %% [markdown]
# # K-Means clusters

# %%
from sklearn.cluster import KMeans

# %%
image_path = os.path.join(dir_baitap, 'vegetables.jpg')
image = cv.imread(image_path)
#(510, 384)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=200x255 at 0x7F27FC683610>

# %%
def Kmeans(img, k):
  r = img.shape[0]
  c = img.shape[1]
  g = img.reshape(r*c, 3)

  kmeans = KMeans(n_clusters=k, random_state=0).fit(g)
  t = kmeans.cluster_centers_[kmeans.labels_]

  return t.reshape(r, c, 3)

# %%
cv2_imshow(Kmeans(image, 6))
# Out:
# <PIL.Image.Image image mode=RGB size=200x255 at 0x7F27DA356BD0>

# %%
image_path = os.path.join(dir_baitap, 'hand.jpg')
image = cv.imread(image_path)
#(510, 384)
cv2_imshow(Kmeans(image, 3))
# Out:
# <PIL.Image.Image image mode=RGB size=384x309 at 0x7F27DA385C10>

# %%
image_path = os.path.join(dir_baitap, 'thuoc.jpg')
image = cv.imread(image_path)
#(510, 384)
cv2_imshow(Kmeans(image, 6))
# Out:
# <PIL.Image.Image image mode=RGB size=199x129 at 0x7F27DA32FB90>

# %%
image_path = os.path.join(dir_baitap, 'airplane.jpg')
image = cv.imread(image_path)
#(510, 384)
cv2_imshow(Kmeans(image, 3))
# Out:
# <PIL.Image.Image image mode=RGB size=675x452 at 0x7F27D9ADFC10>

# %%
def KmeansVer2(img, k):
  r, c, d = img.shape
  g = []

  for i in range(r):
    for j in range(c):
      g.append([img[i][j][0], img[i][j][1], img[i][j][2], i, j])
  kmeans = KMeans(n_clusters=k, random_state=0).fit(g)

  arrcolor = np.random.rand(15, 3)*255
  t = arrcolor[kmeans.labels_]

  img_rst = img.copy()
  i = 0
  for y in range(r):
    for x in range(c):
      img_rst[y][x] = t[i][0:3]
      i = i+1
  return img_rst

# %%
image_path = os.path.join(dir_baitap, 'vegetables.jpg')
image = cv.imread(image_path)
#(510, 384)
cv2_imshow(KmeansVer2(image, 15))
# Out:
# <PIL.Image.Image image mode=RGB size=200x255 at 0x7F27E8CB87D0>

# %%
image_path = os.path.join(dir_baitap, 'dogcat.jpg')
image = cv.imread(image_path)
#(510, 384)
cv2_imshow(Kmeans(image, 10))
# Out:
# <PIL.Image.Image image mode=RGB size=234x184 at 0x7F27D98B7B90>

# %% [markdown]
# # Mean shift

# %%
from sklearn.cluster import MeanShift
from sklearn.cluster import estimate_bandwidth

# %%
def Meanshift(img):
  r = img.shape[0]
  c = img.shape[1]
  g = img.reshape(r*c, 3)

  bw = estimate_bandwidth(g, quantile=0.1, n_samples = 500)
  ms = MeanShift(bandwidth=bw, bin_seeding=True).fit(g)
  t = ms.cluster_centers_[ms.labels_]

  return t.reshape(r, c, 3)

# %%
image_path = os.path.join(dir_baitap, 'thuoc.jpg')
image = cv.imread(image_path)
cv2_imshow(Meanshift(image))
# Out:
# <PIL.Image.Image image mode=RGB size=199x129 at 0x7F27D8048510>

# %%
image_path = os.path.join(dir_baitap, 'airplane.jpg')
image = cv.imread(image_path)
cv2_imshow(Meanshift(image))
# Out:
# <PIL.Image.Image image mode=RGB size=675x452 at 0x7F27D7F50A90>

# %%
image_path = os.path.join(dir_baitap, 'vegetables.jpg')
image = cv.imread(image_path)
cv2_imshow(Meanshift(image))
# Out:
# <PIL.Image.Image image mode=RGB size=200x255 at 0x7F27D9ADED90>
